# %%
'''
optimizing mart sales by predicting placing of goods using association rule learning that is apriori algorithm

'''
# Out:
# '\noptimizing mart sales by predicting placing of goods using association rule learning that is apriori algorithm\n\n'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('Market_Basket_Optimisation.csv',header = None )

# %%
data
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %%
data.shape
# Out:
# (7501, 20)

# %%
# as apriori needs data in alist of transactions

# %%
transactions=[]
for i in range (0,7501):
    transactions.append([str(data.values[i,j])for j in range(1,20)])

# %%
transactions
# Out:
# [['almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['avocado',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
# ...

# %%
for i in transactions:
    print(i)
# Out:
# ['almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil']
# ['meatballs', 'eggs', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ['nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ['avocado', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ['milk', 'energy bar', 'whole wheat rice', 'green tea', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ['nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan']
# ...

# %%
from apyori import apriori

# %%
# calculating minimum support
# taking goods as support which are bought 3 times a week

minimum_support= (3*7)/7501
minimum_support
# Out:
# 0.0027996267164378083

# %%
# confidence controls the number of rules we get so increasing the confidence will lead to less

# %%
rules = apriori(transactions, min_support = 0.003, min_confidence = 0.2, min_lift = 3, min_length = 2)

# %%
# getting the rules found by apriori modelbased on association of goods

# %%
results = list(rules)

# %% [raw]
# # now making results final

# %%
for i in results:
    print(i)
# Out:
# RelationRecord(items=frozenset({'spaghetti', 'bacon'}), support=0.0030662578322890282, ordered_statistics=[OrderedStatistic(items_base=frozenset({'bacon'}), items_add=frozenset({'spaghetti'}), confidence=0.3898305084745763, lift=3.0715531975502066)])
# RelationRecord(items=frozenset({'chicken', 'light cream'}), support=0.004266097853619517, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.2857142857142857, lift=5.278676988036594)])
# RelationRecord(items=frozenset({'mushroom cream sauce', 'escalope'}), support=0.004666044527396347, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.2573529411764706, lift=4.270806220718376)])
# ...

# %%
for item in results:

    # first index of the inner list
    # Contains base item and add item
    pair = item[0] 
    items = [x for x in pair]
    print("Rule: " + items[0] + " -> " + items[1])

    #second index of the inner list
    print("Support: " + str(item[1]))

    #third index of the list located at 0th
    #of the third index of the inner list

    print("Confidence: " + str(item[2][0][2]))
    print("Lift: " + str(item[2][0][3]))
    print("=====================================")
# Out:
# Rule: spaghetti -> bacon
# Support: 0.0030662578322890282
# Confidence: 0.3898305084745763
# Lift: 3.0715531975502066
# ...
# Rule: chicken -> light cream
# Support: 0.004266097853619517
# Confidence: 0.2857142857142857
# Lift: 5.278676988036594
# ...
# Rule: mushroom cream sauce -> escalope
# Support: 0.004666044527396347
# Confidence: 0.2573529411764706
# Lift: 4.270806220718376
# ...
# Rule: pasta -> escalope
# Support: 0.003199573390214638
# Confidence: 0.22641509433962265
# Lift: 3.757388545667056
# ...
# Rule: fromage blanc -> honey
# Support: 0.003199573390214638
# Confidence: 0.2727272727272727
# Lift: 6.218016026526665
# ...
# Rule: ground beef -> frozen vegetables
# Support: 0.010265297960271964
# Confidence: 0.22514619883040934
# Lift: 3.2539915942714845
# ...
# Rule: parmesan cheese -> frozen vegetables
# Support: 0.0030662578322890282
# Confidence: 0.23469387755102042
# Lift: 5.147481799737439
# ...
# Rule: shrimp -> frozen vegetables
# Support: 0.006265831222503666
# Confidence: 0.22274881516587677
# ...
